# %%
import pandas as pd 
import numpy as np

# %%
data = "TMD_Datasets/dataset.csv"
dataset = pd.read_csv(data, header=None)

col_names = ['Distance','Speed', 'Acceleration', 'Avg Speed', 'STD speed', 'Max Speed', '75% percentile speed' , '50% percentile speed','Avg Acc', 'STD Acc' ,'Mode']
dataset.columns = col_names

dataset.dropna(inplace=True)

features = ['Distance','Speed', 'Acceleration', 'Avg Speed', 'STD speed', 'Max Speed', '75% percentile speed' , '50% percentile speed','Avg Acc', 'STD Acc']
classes = ['Bike','Bus', 'Subway','Car', 'Walk']

dataset['Mode'].value_counts()
# Out:
# Subway    22281
# Car        5949
# Walk       1965
# Bus        1859
# Bike       1307
# Name: Mode, dtype: int64

# %% [markdown]
# ## Visualizing the features in the dataset
# -Each mode of the dataset for each of the columns of the decision (each feature) is visualized using a histogram graph
#
# -Visualizing these graphs can help understand the distribution of every feature in the dataset
#
# -Understanding the distribution can help validate if using the features would be beneficial for the model
#
# -If one of the features, has somewhat the same distribution for all of the different modes of transportation, then there is not enough of a distinction to differentiate between the different modes of transportation which somewhat suggests that using this feature would not really add any benefits to model and can be potentially removed from the dataset to simplify the model training process

# %%
# Distance Distribution
bins_distance = np.arange(0,0.1,0.0005)
dataset.hist(column = 'Distance', by = 'Mode', bins=bins_distance, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Speed Distribution
bins_speed = np.arange(0,110,5)
dataset.hist(column = 'Speed', by = 'Mode', bins=bins_speed, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Acceleration Distribution
bins_acceleration = np.arange(-10000,10000,100)
dataset.hist(column = 'Acceleration', by = 'Mode', bins=bins_acceleration, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Average Speed Distribution
bins_avg_speed = np.arange(0,110,5)
dataset.hist(column = 'Avg Speed', by = 'Mode', bins=bins_avg_speed, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Standard Deviation of Speed Distribution
bins_STD_speed = np.arange(0,20,0.5)
dataset.hist(column = 'STD speed', by = 'Mode', bins=bins_STD_speed, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Max Speed Distribution
bins_max_speed = np.arange(0,110,5)
dataset.hist(column = 'Max Speed', by = 'Mode', bins=bins_max_speed, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# 75% Percentile of Speed Distribution
bins_75_speed = np.arange(0,110,5)
dataset.hist(column = '75% percentile speed', by = 'Mode', bins=bins_75_speed, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# 50% Percentile of Speed Distribution
bins_50_speed = np.arange(0,110,5)
dataset.hist(column = '50% percentile speed', by = 'Mode', bins=bins_50_speed, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Average Acceleration Distribution
bins_avg_acc = np.arange(-10000,10000,100)
dataset.hist(column = 'Avg Acc', by = 'Mode', bins=bins_avg_acc, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)

# %%
# Standard Deviation of Acceleration Distribution
bins_STD_acc = np.arange(0,20000,50)
dataset.hist(column = 'STD Acc', by = 'Mode', bins=bins_STD_acc, figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'Bike'}>,
#         <Axes: title={'center': 'Bus'}>],
#        [<Axes: title={'center': 'Car'}>,
#         <Axes: title={'center': 'Subway'}>],
#        [<Axes: title={'center': 'Walk'}>, <Axes: >]], dtype=object)
